# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/drive/My Drive/Datasets/Employee-Attrition.csv')

# %%
dataset.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
dataset.describe(exclude='object').transpose()
# Out:
#                            count          mean  ...       75%      max
# Age                       1470.0     36.923810  ...     43.00     60.0
# DailyRate                 1470.0    802.485714  ...   1157.00   1499.0
# DistanceFromHome          1470.0      9.192517  ...     14.00     29.0
# Education                 1470.0      2.912925  ...      4.00      5.0
# EmployeeCount             1470.0      1.000000  ...      1.00      1.0
# EmployeeNumber            1470.0   1024.865306  ...   1555.75   2068.0
# EnvironmentSatisfaction   1470.0      2.721769  ...      4.00      4.0
# HourlyRate                1470.0     65.891156  ...     83.75    100.0
# JobInvolvement            1470.0      2.729932  ...      3.00      4.0
# JobLevel                  1470.0      2.063946  ...      3.00      5.0
# JobSatisfaction           1470.0      2.728571  ...      4.00      4.0
# MonthlyIncome             1470.0   6502.931293  ...   8379.00  19999.0
# ...

# %%
dataset.describe(include='object').transpose()
# Out:
#                count unique                     top  freq
# Attrition       1470      2                      No  1233
# BusinessTravel  1470      3           Travel_Rarely  1043
# Department      1470      3  Research & Development   961
# EducationField  1470      6           Life Sciences   606
# Gender          1470      2                    Male   882
# JobRole         1470      9         Sales Executive   326
# MaritalStatus   1470      3                 Married   673
# Over18          1470      1                       Y  1470
# OverTime        1470      2                      No  1054

# %% [markdown]
# Removing unnecessary columns

# %%
dataset = dataset.drop(['EmployeeCount','EmployeeNumber','Over18','StandardHours'], axis=1)

# %%
# fig, axes = plt.subplots(31,3)
# fig = plt.figure(figsize=(8, 20))

for x in dataset.columns:
  if x == 'Attrition':
    continue
  plt.figure(figsize=(20,10))
  sns.countplot(data=dataset, x=x, hue='Attrition')
  plt.show()

# %%
dataset.isnull().any()
# Out:
# Age                         False
# Attrition                   False
# BusinessTravel              False
# DailyRate                   False
# Department                  False
# DistanceFromHome            False
# Education                   False
# EducationField              False
# EnvironmentSatisfaction     False
# Gender                      False
# HourlyRate                  False
# JobInvolvement              False
# JobLevel                    False
# JobRole                     False
# JobSatisfaction             False
# MaritalStatus               False
# MonthlyIncome               False
# MonthlyRate                 False
# NumCompaniesWorked          False
# OverTime                    False
# PercentSalaryHike           False
# PerformanceRating           False
# RelationshipSatisfaction    False
# StockOptionLevel            False
# TotalWorkingYears           False
# TrainingTimesLastYear       False
# WorkLifeBalance             False
# ...

# %%
# Checking correlation between independent variables
def correlation_heatmap(train):
    correlations = train.corr()
    
    mask = np.zeros_like(correlations, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    fig, ax = plt.subplots(figsize=(40,40))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f', cmap='coolwarm',
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70}, mask=mask)
    plt.show()
    
correlation_heatmap(dataset)

# %%
#Getting all features
features=[]
for ft in dataset.columns:
    if dataset[ft].dtype=='O' and ft != 'Attrition':
        features.append(ft)

# %%
#OneHot Encoding
for f in features:
    dataset = pd.get_dummies(dataset, columns=[f])

# %%
#Label Encoding
# from sklearn.preprocessing import LabelEncoder
# encoder = LabelEncoder()

# for f in features:
#     dataset[f] = encoder.fit_transform(dataset[f])

# %%
dataset['Attrition'] = dataset['Attrition'].map({'Yes':1, 'No':0})

dataset.head()
# Out:
#    Age  Attrition  DailyRate  ...  MaritalStatus_Single  OverTime_No  OverTime_Yes
# 0   41          1       1102  ...                     1            0             1
# 1   49          0        279  ...                     0            1             0
# 2   37          1       1373  ...                     1            0             1
# 3   33          0       1392  ...                     0            0             1
# 4   27          0        591  ...                     0            1             0
#
# [5 rows x 52 columns]

# %%
X = dataset.drop(['Attrition'], axis=1)
Y = dataset['Attrition']

# %%
from sklearn.preprocessing import StandardScaler

scaledX = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split  

trainX, testX, trainY, testY = train_test_split(scaledX, Y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
seed = 42
# Random Forest parameters
rf_params = {
    'n_estimators': 1000,
    'random_state' : seed,
    'verbose': 0
    }

# rf_params = {
#     'bootstrap': False,
#     'max_depth': 70,
#     'max_features': 'sqrt',
#     'min_samples_leaf': 1,
#     'min_samples_split': 5,
#     'n_estimators': 1600,
#     'random_state' : seed,
#     }

rf = RandomForestClassifier(**rf_params)

rf.fit(trainX, trainY)
rf_predictions = rf.predict(testX)
print("Accuracy score: {}".format(accuracy_score(testY, rf_predictions)))
print("="*80)
print(classification_report(testY, rf_predictions))
# Out:
# Accuracy score: 0.8639455782312925
# ...
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       243
#            1       0.87      0.25      0.39        51
#
#     accuracy                           0.86       294
#    macro avg       0.87      0.62      0.66       294
# weighted avg       0.86      0.86      0.83       294

# %%
from sklearn.model_selection import RandomizedSearchCV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rf = RandomForestClassifier()

rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, 
                               n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)

rf_random.fit(trainX, trainY)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:  9.8min finished
# RandomizedSearchCV(cv=3, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     max_samples=None,
# ...

# %%
rf_random.best_params_
# Out:
# {'bootstrap': False,
#  'max_depth': 70,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 1600}

# %%
rf_predictions = rf_random.best_estimator_.predict(testX)
print("Accuracy score: {}".format(accuracy_score(testY, rf_predictions)))
print("="*80)
print(classification_report(testY, rf_predictions))
# Out:
# Accuracy score: 0.8741496598639455
# ...
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       243
#            1       0.94      0.29      0.45        51
#
#     accuracy                           0.87       294
#    macro avg       0.90      0.65      0.69       294
# weighted avg       0.88      0.87      0.85       294
